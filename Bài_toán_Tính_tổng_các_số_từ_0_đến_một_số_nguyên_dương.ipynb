# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903922-lang/Nguyen-Van-Du/blob/main/B%C3%A0i_to%C3%A1n_T%C3%ADnh_t%E1%BB%95ng_c%C3%A1c_s%E1%BB%91_t%E1%BB%AB_0_%C4%91%E1%BA%BFn_m%E1%BB%99t_s%E1%BB%91_nguy%C3%AAn_d%C6%B0%C6%A1ng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
n=int(input("n="))
S= (n*(n+1)/2)
print("Tổng từ 0 đến",n,"=",S)
# Out:
# n=5
# Tổng từ 0 đến 5 = 15.0

# %%
n = int(input("Số nguyên dương n = "))

tong = 0
for i in range(0, n + 1):
    tong += i

print("Tổng từ 0 đến", n, "=", tong)
# Out:
# Số nguyên dương n = 5
# Tổng từ 0 đến 5 = 15
